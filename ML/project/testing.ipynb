# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# importing initial datasets from persistent landing
thyroid_df = pd.read_csv('landing/persistent/all_thyroid.csv') # all_thyroid.csv
thyroid_test_df = pd.read_csv('landing/persistent/all_thyroid_test.csv') # all_thyroid_test.csv
conditions_df = pd.read_csv('landing/persistent/all_conditions.csv') # all_conditions.csv
conditions_test_df = pd.read_csv('landing/persistent/all_conditions_test.csv') # all_conditions_test.csv

# %%
thyroid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  2799 non-null   float64
#  1   sex                  2690 non-null   object
#  2   on_thyroxine         2800 non-null   object
#  3   query_on_thyroxine   2800 non-null   object
#  4   on_antithyroid_meds  2800 non-null   object
#  5   sick                 2800 non-null   object
#  6   pregnant             2800 non-null   object
#  7   thyroid_surgery      2800 non-null   object
#  8   I131_treatment       2800 non-null   object
#  9   query_hypothyroid    2800 non-null   object
#  10  query_hyperthyroid   2800 non-null   object
#  11  lithium              2800 non-null   object
#  12  goitre               2800 non-null   object
#  13  tumor                2800 non-null   object
#  14  hypopituitary        2800 non-null   object
# ...

# %%
plt.figure(figsize=(10,8))
sns.set_theme(style='ticks')
sns.stripplot(x=thyroid_df.target_hyper, y=thyroid_df.FTI, palette='Set1', linewidth=0.6, jitter= 0.3)
# Out:
# <AxesSubplot:xlabel='target_hyper', ylabel='FTI'>

# %%
plt.figure(figsize=(10,8))
sns.set_theme(style='ticks')
sns.barplot(x=thyroid_df.target_hyper, y=thyroid_df.FTI, palette='Set1')
# Out:
# <AxesSubplot:xlabel='target_hyper', ylabel='FTI'>
